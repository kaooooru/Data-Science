# %% [markdown]
# # import

# %%
# imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Data loading

# %%
# Load data from csv file "binary_data.csv"
# No headers
data = pd.read_csv('./binary_data.csv',header=None)
data
# Out:
#             0          1    2
# 0   34.623660  78.024693  0.0
# 1   30.286711  43.894998  0.0
# 2   35.847409  72.902198  0.0
# 3   60.182599  86.308552  1.0
# 4   79.032736  75.344376  1.0
# ..        ...        ...  ...
# 95  83.489163  48.380286  1.0
# 96  42.261701  87.103851  1.0
# 97  99.315009  68.775409  1.0
# 98  55.340018  64.931938  1.0
# 99  74.775893  89.529813  1.0
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Handle missing values

# %%
# isnull will create a new data frame
# if the entry is nan, it would put True
# otherwise it would put False
data.isnull()
# Out:
#         0      1      2
# 0   False  False  False
# 1   False  False  False
# 2   False  False  False
# 3   False  False  False
# 4   False  False  False
# ..    ...    ...    ...
# 95  False  False  False
# 96  False  False  False
# 97  False  False  False
# 98  False  False  False
# 99  False  False  False
#
# [100 rows x 3 columns]

# %%
# It sums up the number of True on each column
data.isnull().sum()
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
# We want to drop those rows where some entries are nan
data = data.dropna()
# Check if they are dropped
data.isnull().sum()
# Out:
# 0    0
# 1    0
# 2    0
# dtype: int64

# %% [markdown]
# ## Data Visulaization

# %%
# The first two columns are X
# The last column is y
X = data.iloc[:,0:1]
y = data.iloc[:,-1]

# ones: We want to get all the rows where y=1
# zeros: We want to get all the rows where y=0
ones = data.loc[y==1]
zeros = data.loc[y==0]

# Use different color to visualize scatter plot
plt.scatter(ones.iloc[:,0], ones.iloc[:,1], s=20)
plt.scatter(zeros.iloc[:,0], zeros.iloc[:,1], s=20)

# %% [markdown]
# ## Train Validation spliting

# %%
from sklearn.model_selection import train_test_split
# split the train and validation set randomly in ratio 9:1
train, validation = train_test_split(data,test_size=0.1)

# %% [markdown]
# ##Data transformation

# %%
def data_transform(data):
  # Transform the data format to the format that model accepts
  # data frame -> numpy array
  X, y = data.iloc[:, :-1], data.iloc[:, -1]
  X = np.array(X)
  y = np.array(y).reshape(-1,1)
  return X, y

X_train, y_train = data_transform(train)
X_val, y_val = data_transform(validation)

# %% [markdown]
# ##Gaussian noise

# %%
# initializa a Gaussian noise of mean 0, standard deviation 10
noise = np.random.normal(loc=0,scale=10,size=X_train.shape)
X_train_noisy = X_train + noise

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], s=20, color='g')
plt.scatter(X_train_noisy[:,0], X_train_noisy[:,1], s=20, color='b')

# %% [markdown]
# # Model Architecture

# %%
class YourLogisticRegression:
    def __init__(self, learning_rate=0.001, epochs=500000):
      # initialize model parameters, hyperparameters and other variables
      self.learning_rate = learning_rate
      self.epochs = epochs
      self.train_costs = []
      self.val_costs = []
    
    def sigmoid(self, x):
      # Implemente the function of sigmoid
      return 1/(1+np.exp(-(x)))

    def cost(self, h, y):
      # Implemente the cost function
      # N =  float(len(y))
      return np.mean(-y*np.log(h)-(1-y)*np.log(1-h))
    
    def add_noise(self, X):
      noise = np.random.normal(loc=0,scale=10,size=X.shape)
      X = X + noise
      return X

    def fit(self, X, y, X_val, y_val, with_noise=False):
      # concat x_0=1 in X for the bias term
      # X = [1, X]

      X = np.concatenate((np.ones((X.shape[0], 1)), X), axis=1)
      y = y.flatten()
      X_val = np.concatenate((np.ones((X_val.shape[0], 1)), X_val), axis=1)
      y_val = y_val.flatten()
      
      # weights including w,b, are initialized
      # weights = [b, w1, w2]
      self.weights = np.zeros(X.shape[1])
      
      cost_lst = []
      # import pdb
      for i in range(self.epochs):
        if with_noise == True:
          self.add_noise(X)

        y_pred = self.sigmoid(np.dot(X, self.weights))
        # compute the gradient with respect to weights
        # pdb.set_trace()
        gradient = -np.dot(X.T,(y-y_pred))
        self.weights -= self.learning_rate * gradient/X.shape[0]
        
        cost = self.cost(y_pred, y)
        cost_lst.append([i,cost])

        if i % 100000 == 0:
          # compute cost for validation set
          y_val_pred = self.sigmoid(np.dot(X_val, self.weights))
          val_cost = self.cost(y_val_pred, y_val)
          self.val_costs.append([i, val_cost])

          print('Epoch', i, ': train cost is', cost, ', validation cost is', val_cost)

      self.train_costs = cost_lst
      self.coef_ = self.weights[1:].reshape(1,-1)
      self.intercept_ = self.weights[0].reshape(1,-1)

    def predict(self, X):
      X = np.concatenate((np.ones((X.shape[0], 1)), X), axis=1)
      pred = self.sigmoid(np.dot(X, self.weights))
      return pred.round()

# %% [markdown]
# #Model Training

# %% [markdown]
# ## Scikit learn model

# %%
# Using scikit-learn to train logistic regression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Print the accuracy of the model
y_pred = model.predict(X_train)
accuracy = accuracy_score(y_train.flatten(), y_pred)
print('The accuracy on training set is {}'.format(accuracy))
# Out:
# The accuracy on training set is 0.8809523809523809

# %%
# Decision boundary
# y = w1 x1 + w2 x2 + b
# coef_ = [[w1, w2]]
# intercept_ = [b]
plt.scatter(ones.iloc[:, 0], ones.iloc[:, 1], s=20)
plt.scatter(zeros.iloc[:, 0], zeros.iloc[:, 1], s=20)
xx = np.linspace(0,100)
yy = -(model.coef_[0][0]/model.coef_[0][1])*xx-(model.intercept_/model.coef_[0][1])
plt.plot(xx, yy, color='g')

# %% [markdown]
# ## Your logistic regression model

# %%
 # Train your own model
your_model = YourLogisticRegression()
your_model.fit(X_train, y_train, X_val, y_val)
# Out:
# Epoch 0 : train cost is 0.6931471805599454 , validation cost is 0.718476219847102
# Epoch 100000 : train cost is 0.39127286676961387 , validation cost is 0.39646220925452913
# Epoch 200000 : train cost is 0.3233346818029171 , validation cost is 0.31667291035974887
# Epoch 300000 : train cost is 0.2918307144848856 , validation cost is 0.27642800077245067
# Epoch 400000 : train cost is 0.2736802492446359 , validation cost is 0.2515532607105726

# %%
y_pred = your_model.predict(X_train)
accuracy = accuracy_score(y_train.flatten(), y_pred)
print('The accuracy on training set is {}'.format(accuracy))
# Out:
# The accuracy on training set is 0.8690476190476191

# %%
# Decision boundary
# Copy your implementation above
plt.scatter(ones.iloc[:, 0], ones.iloc[:, 1], s=20)
plt.scatter(zeros.iloc[:, 0], zeros.iloc[:, 1], s=20)
xx = np.linspace(0,100)
yy = -(your_model.coef_[0][0]/your_model.coef_[0][1])*xx-(your_model.intercept_/your_model.coef_[0][1])
plt.plot(xx, yy.T, color='g')

# %% [markdown]
# ## Your logistic regression model with gaussian noise

# %%
# Train your own model with Gaussian noise
your_model_noisy = YourLogisticRegression()
your_model_noisy.fit(X_train_noisy, y_train, X_val, y_val)
y_pred = your_model_noisy.predict(X_train_noisy)
accuracy = accuracy_score(y_train.flatten(), y_pred)
print('The accuracy on training set is {}'.format(accuracy))
# Out:
# Epoch 0 : train cost is 0.6931471805599454 , validation cost is 0.7137293587871499
# Epoch 100000 : train cost is 0.44633929108392906 , validation cost is 0.42337884089341815
# Epoch 200000 : train cost is 0.4004494456861767 , validation cost is 0.35461921771364585
# Epoch 300000 : train cost is 0.3821963879788039 , validation cost is 0.32141369308070233
# Epoch 400000 : train cost is 0.37328510033801504 , validation cost is 0.30203703998512277
# The accuracy on training set is 0.8452380952380952

# %%
# Correctly apply Gaussian noise
your_model_noisy = YourLogisticRegression()
X_train_noisy = your_model_noisy.add_noise(X_train)
your_model_noisy.fit(X_train_noisy, y_train, X_val, y_val, with_noise=True)
y_pred = your_model_noisy.predict(X_train_noisy)
accuracy = accuracy_score(y_train.flatten(), y_pred)
print('The accuracy on training set is {}'.format(accuracy))
# Out:
# Epoch 0 : train cost is 0.6931471805599454 , validation cost is 0.7046393442726833
# Epoch 100000 : train cost is 0.4775352185623908 , validation cost is 0.43458973359377734
# Epoch 200000 : train cost is 0.4395456658584216 , validation cost is 0.3656273417460814
# Epoch 300000 : train cost is 0.4246267225700283 , validation cost is 0.3313211363358725
# Epoch 400000 : train cost is 0.4174708464662737 , validation cost is 0.310985577971471
# The accuracy on training set is 0.8095238095238095

# %% [markdown]
# #Model evaluation

# %% [markdown]
# ## Train and Validation cost

# %%
# Visualize the cost of training set and testing set
# Use the model without Gaussian noise
plt.plot(np.array(your_model_noisy.train_costs)[:,0], np.array(your_model_noisy.train_costs)[:,1], color='b')
plt.plot(np.array(your_model_noisy.val_costs)[:,0], np.array(your_model_noisy.val_costs)[:,1], color='r')
plt.title('Train Cost Curve', fontsize=16)
plt.xlabel('epoch', fontsize=14)
plt.ylabel('cost', fontsize=14)

plt.show()

# %%
# Visualize the cost of training set and testing set
# Use the model with Gaussian noise
plt.plot(np.array(your_model.train_costs)[:,0], np.array(your_model.train_costs)[:,1], color='b')
plt.plot(np.array(your_model.val_costs)[:,0], np.array(your_model.val_costs)[:,1], color='r')
plt.title('Train Cost Curve', fontsize=16)
plt.xlabel('epoch', fontsize=14)
plt.ylabel('cost', fontsize=14)

plt.show()

# %% [markdown]
# #Interview questions

# %% [markdown]
# *   What is the purpose/benefits of adding Gaussian noise?
# *   Why is the decision boudary a linear function?
# *   Can logistic regression classify high dimensional data?
# *   Can logistic regression classify non-linear separable data?

# %% [markdown]
# 1. Adding the Gaussian noise generalize the data which can avoid model overfit. Expand training data set.
# 2. In this question, the data is classified into 2 types. The equation for decision boundary is wx+b=m it's a linear function after the equation is expanded.
# 3. High dimensional data can be classify by logistic regression which means x become a more that 2-D vetor.
# 4. Non-linear separable can't be separated by logistic regression because the decision boundary is a linear function.
